# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sample Code

# %%
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %% [markdown]
# ## Part 1 Cython

# %%
# %load_ext cythonmagic

# %%
#%%cython

# %%
# %%file mdb1.pyx
#
# import numpy as np
# from numpy cimport complex128_t, float_t
#
# cdef mandel1(float_t x, float_t y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef int i
#     cdef complex128_t c = complex(x, y)
#     cdef complex128_t z = 0.0j
#
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal1(int Nx,int Ny,int xmin,int xmax, int ymin, int ymax,int max_iter):
#     """Create and return a fractal image"""
#
#     cdef float_t[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float_t dx = (xmax - xmin) * 1. / Nx
#     cdef float_t dy = (ymax - ymin) * 1. / Ny
#
#     cdef float_t rpart
#     cdef float_t ipart
#     cdef float_t color
#     cdef int x
#     cdef int y
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel1(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image
# Out:
# Overwriting mdb1.pyx

# %%
# !cython -a mdb1.pyx

# %%
# %%cython
#
# ## Not sure how to call function from mdb1.pyx, so I rewrite it here again
# import numpy as np
# from numpy cimport complex128_t, float_t
#
# cdef mandel1(float_t x, float_t y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef int i
#     cdef complex128_t c = complex(x, y)
#     cdef complex128_t z = 0.0j
#
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal1(int Nx,int Ny,int xmin,int xmax, int ymin, int ymax,int max_iter):
#     """Create and return a fractal image"""
#
#     cdef float_t[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float_t dx = (xmax - xmin) * 1. / Nx
#     cdef float_t dy = (ymax - ymin) * 1. / Ny
#
#     cdef float_t rpart
#     cdef float_t ipart
#     cdef float_t color
#     cdef int x
#     cdef int y
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel1(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
image = create_fractal1(300, 200, -2, 1, -1, 1, 10)

# %%
plt.imshow(image, cmap=plt.cm.jet)

# %%
# Compare time
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal1(300, 200, -2, 1, -1, 1, 20)
# Out:
# 1 loops, best of 3: 377 ms per loop
# 100 loops, best of 3: 16.4 ms per loop

# %% [markdown]
# ## Part 2 Numba

# %%
from numba import autojit

# %%
@autojit
def mandel2(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

@autojit
def create_fractal2(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=np.float64)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel2(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %% [markdown]
# ## Part 3 Compare Times

# %%
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal1(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal2(300, 200, -2, 1, -1, 1, 20)
# Out:
# 1 loops, best of 3: 384 ms per loop
# 100 loops, best of 3: 16.3 ms per loop
# 1 loops, best of 3: 2.97 ms per loop

# %% [markdown]
# ## Part 4 Choose best method (Numba) and generate Mandelbrot Set

# %%
newimage = create_fractal2(2400, 1600, -0.9, -0.55, -0.5, -0.08, 256)
plt.imshow(newimage, cmap='gist_ncar')
