# %% [markdown]
# ### Kolby Weisenburger
#
# ### Homework 7 - Mandelbrot Set

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
#plt.imshow(image, cmap=plt.cm.jet)

# %% [markdown]
# ### PART 1 - Cython

# %%
# %load_ext cythonmagic

# %%
# %%cython
# import numpy as np
# from numpy cimport float_t
#
# def mandel_cy(int x, int y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef complex c = complex(x, y)
#     cdef complex z = 0.0j
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# def create_fractal_cy(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     """Create and return a fractal image"""
#     image = np.zeros((Ny, Nx))
#     cdef double dx = (xmax - xmin) * 1. / Nx
#     cdef double dy = (ymax - ymin) * 1. / Ny
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mandel_cy(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
# %%file mandel_cy.pyx
# def mandel_cy(int x, int y, int max_iter):
#     """
#     Given z = x + iy and max_iter, determine whether the candidate
#     is in the mandelbrot set for the given number of iterations
#     """
#     cdef double complex c = complex(x, y)
#     cdef double complex z = 0.0j
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
# Out:
# Overwriting mandel_cy.pyx

# %%
# !cython -a mandel_cy.pyx

# %% [markdown]
# ### PART 2 - Numba

# %%
from numba import autojit

# %%
@autojit
def mandel_nu(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

@autojit
def create_fractal_nu(min_x, max_x, min_y, max_y, image, max_iter):
  height = image.shape[0]
  width = image.shape[1]

  pixel_size_x = (max_x - min_x) / width
  pixel_size_y = (max_y - min_y) / height
    
  for x in range(width):
    real = min_x + x * pixel_size_x
    for y in range(height):
      imag = min_y + y * pixel_size_y
      color = mandel_nu(real, imag, max_iter)
      image[y, x] = color

# %% [markdown]
# ### PART 3 - Time it

# %%
print "Python only:"
# %timeit mandel(0,0,10)
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
print "Typed Cython:"
# %timeit mandel_cy(0,0,10)
# %timeit create_fractal_cy(300, 200, -2, 1, -1, 1, 20)
print "Numba:"
# %timeit mandel_nu(0,0,10)
image = np.zeros((1024, 1536), dtype = np.float64)
# %timeit create_fractal_nu(-2.0, 1.0, -1.0, 1.0, image, 20)
# Out:
# Python only:
# 100000 loops, best of 3: 4.27 µs per loop
# 1 loops, best of 3: 261 ms per loop
# Typed Cython:
# 1000000 loops, best of 3: 306 ns per loop
# 10 loops, best of 3: 30.6 ms per loop
# Numba:
# 1000000 loops, best of 3: 412 ns per loop
# 10 loops, best of 3: 63.4 ms per loop

# %% [markdown]
# ### PART 4 - Most beautiful Mandelbrot plot

# %%
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

import cubehelix 
cx = cubehelix.cmap(rot=.5)

# %%
image = np.zeros((1024, 1536), dtype = np.float64)
create_fractal_nu(-2.0, 1.0, -1.0, 1.0, image, 256) 
plt.imshow(image, cmap=cx)
