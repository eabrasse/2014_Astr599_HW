# %% [markdown]
# Homework: classification and Regression of Astonomical Sources
# 1. Classification: Labelling photometric sources

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
from astroML.datasets import fetch_rrlyrae_combined
from sklearn.cross_validation import train_test_split

X, y = fetch_rrlyrae_combined()

# For now, we'll only fit the first two colors
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
N_plot = 5000
plt.scatter(X[-N_plot:, 0], X[-N_plot:, 1], c=y[-N_plot:],
            edgecolors='none')
plt.xlabel('u-g color')
plt.ylabel('g-r color');

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train[::5], y_train[::5])
y_pred = clf.predict(X_test)

# %%
print(np.sum(y_pred == y_test))
print(np.sum(y_pred != y_test))
# Out:
# 23194
# 92

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23169
#    RR Lyrae       0.62      0.56      0.59       117
#
# avg / total       1.00      1.00      1.00     23286

# %% [markdown]
# Note on the meaning of these terms:
#
# \[ {\rm precision} \equiv \frac{\rm true~positives}{\rm true~positives + false~positives} \]
#
# \[ {\rm recall} \equiv \frac{\rm true~positives}{\rm true~positives + false~negatives} \]
#
# \[ F_1 \equiv \frac{2 \cdot \rm precision \cdot recall}{\rm precision + recall} \]
#
# The range for precision, recall, and F1 score is 0 to 1, with 1 being perfect. Often in astronomy, we call the recall the completeness, and (1 - precision) the contamination.
# Because this is an unbalanced dataset, we see that the RR Lyrae stars are completely overwhelmed by the larger number of normal Main Sequence stars.
#
# Exercise: Use another classifier and try to improve on this precision/recall score.

# %%
from sklearn.ensemble import RandomForestClassifier 
clf = RandomForestClassifier(n_estimators=6, criterion='entropy')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23169
#    RR Lyrae       0.67      0.46      0.55       117
#
# avg / total       1.00      1.00      1.00     23286

# %% [markdown]
# Exercise 2: Photometric Redshifts

# %%
from astroML.datasets import fetch_sdss_specgals
data = fetch_sdss_specgals()

# put magnitudes in a matrix
X = np.vstack([data['modelMag_%s' % f] for f in 'ugriz']).T
y = data['z']

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LinearRegression
est = LinearRegression()
est.fit(X_train, y_train)
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)
# Out:
# (0, 0.6)

# %%
rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(rms)
# Out:
# 0.0330909330707

# %% [markdown]
# Task: Try to improve on this result using another regression algorithm.

# %%
#this worked once, the continues to crash
#from sklearn.svm import SVR
#est = SVR()
#est.fit(X_train[::3], y_train[::3])
#y_pred = est.predict(X_test)

#plt.plot(y_test, y_pred, ',k')
#plt.plot([0, 1], [0, 1], ':k')
#plt.xlim(0, 0.6)
#plt.ylim(0, 0.6)

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
est = RFR()
est.fit(X_train[::5], y_train[::5])
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)
# Out:
# (0, 0.6)
