# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

def create_fractal(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    """Create and return a fractal image"""
    image = np.zeros((Ny, Nx), dtype=float)
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mandel(rpart, ipart, max_iter)
            image[y, x] = color
    return image

# %%
image = create_fractal(300, 200, -2, 1, -1, 1, 20)
plt.imshow(image, cmap=plt.cm.jet)

# %%
# %load_ext cythonmagic
# Out:
# The cythonmagic extension is already loaded. To reload it, use:
#   %reload_ext cythonmagic

# %%
# %%file fractalc.pyx
# import numpy as np
# from numpy cimport float_t , complex128_t
#
# cdef int mancy(float_t x, float_t y, int max_iter):
#     cdef complex128_t c,z
#     c = complex(x,y)
#     z = 0.0j
#     cdef int i
#
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# cdef float_t[:,:] create_fractal_c(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     cdef float_t[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float_t dx, dy, rpart, ipart
#     cdef int x, y, color
#     dx = (xmax - xmin) * 1.0  / Nx
#     dy = (ymax - ymin) * 1.0 / Ny
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mancy(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image
# Out:
# Writing fractalc.pyx

# %%
# !cython -a fractalc.pyx

# %%
# %%cython
# import numpy as np
# from numpy cimport float_t , complex128_t
#
# cdef int mancy(float_t x, float_t y, int max_iter):
#     cdef complex128_t c,z
#     c = complex(x,y)
#     z = 0.0j
#     cdef int i
#
#     for i in range(max_iter):
#         z = z*z + c
#         if (z.real*z.real + z.imag*z.imag) >= 4:
#             return i
#
#     return max_iter
#
# cpdef float_t[:,:] create_fractal_c(int Nx, int Ny, int xmin, int xmax, int ymin, int ymax, int max_iter):
#     cdef float_t[:,:] image = np.zeros((Ny, Nx), dtype=float)
#     cdef float_t dx, dy, rpart, ipart
#     cdef int x, y, color
#     dx = (xmax - xmin) * 1.0  / Nx
#     dy = (ymax - ymin) * 1.0 / Ny
#
#     for x in range(Nx):
#         rpart = xmin + x * dx
#         for y in range(Ny):
#             ipart = ymin + y * dy
#             color = mancy(rpart, ipart, max_iter)
#             image[y, x] = color
#     return image

# %%
from numba import autojit
import numpy as np
def mandel(x, y, max_iter):
    """
    Given z = x + iy and max_iter, determine whether the candidate
    is in the mandelbrot set for the given number of iterations
    """
    c = complex(x, y)
    z = 0.0j
    for i in range(max_iter):
        z = z*z + c
        if (z.real*z.real + z.imag*z.imag) >= 4:
            return i

    return max_iter

mannb = autojit(mandel)


def create_fractal_n(Nx, Ny, xmin, xmax, ymin, ymax, max_iter):
    image = np.zeros((Ny, Nx))
    dx = (xmax - xmin) * 1. / Nx
    dy = (ymax - ymin) * 1. / Ny
    
    for x in range(Nx):
        rpart = xmin + x * dx
        for y in range(Ny):
            ipart = ymin + y * dy
            color = mannb(rpart, ipart, max_iter)
            image[y, x] = color
    return image

fractal_nb = autojit(create_fractal_n)

# %%
# %timeit create_fractal(300, 200, -2, 1, -1, 1, 20)
# %timeit create_fractal_c(300, 200, -2, 1, -1, 1, 20)
# %timeit fractal_nb(300, 200, -2, 1, -1, 1, 20)

#The results of this strike me as fishy. 
#For some reason ipython did not like me changing the function name from create_funtion
# Out:
# 1 loops, best of 3: 517 ms per loop
# 10 loops, best of 3: 22 ms per loop
# 1 loops, best of 3: 4.61 ms per loop

# %%
pretty_image = fractal_nb(5000, 500, -2, 1, -1.5, 2, 256)

plt.imshow(pretty_image, cmap=plt.cm.prism)
plt.xlim(950,1300)
plt.ylim(240,180)
# Out:
# (240, 180)
