# %% [markdown]
# # Homework 9

# %% [markdown]
# Leah Bakst

# %% [markdown]
# 12/1/14

# %% [markdown]
# * *I had a great deal of trouble with this assignment. In theory I was trying to use the scatter function to distribute the max depth options between the parallel processors and try them with each n_estimator. Although I'm pretty sure I created the models in a distributed fashion, I couldn't then calculate the score to assess how well each did. Had I been able to do that I would have then gathered the scores and subsequently found the best score and determined which number of estimators and max depth generated it. Unfortunately I was unable to do so.*

# %%
from IPython import parallel
clients = parallel.Client(profile='default')
clients.block = True
#view = clients.load_balanced_view()
dview = clients[:]

# %%
# %matplotlib inline
# %px import numpy as np
# %px import matplotlib.pyplot as plt

# %%
from astroML.datasets import fetch_sdss_specgals
data = fetch_sdss_specgals()

#put magnitudes in a matrix
X = np.vstack([data['modelMag_%s' % f] for f in 'ugriz']).T
y = data['z']

# down-sample the data for speed
dview['X'] = X[::10]
dview['y'] = y[::10]

# %%
# %px from sklearn.ensemble import RandomForestRegressor
# %px from sklearn.cross_validation import cross_val_score, StratifiedKFold

#define the model with the given value of C
# %px model = RandomForestRegressor(n_estimators=10, max_depth=3)

#compute the scores via cross-validation
# %px scores = cross_val_score(model, X, y, scoring='r2', cv=3)

#print the mean of the cross-validation scores
# %px score = np.mean(scores)
# %px print(score)
# Out:
# [stdout:0] 0.55225693187
# [stdout:1] 0.552437517817
# [stdout:2] 0.553541056694
# [stdout:3] 0.552725625172

# %%
nest1 = range(1,101)
m_d1 = range(1,101)

def parallel_r2(dview,nest,m_d):
    dview['nest'] = nest
    dview.scatter('m_d',m_d)
    for dview['j'] in dview['m_d']:
        for dview['i'] in dview['nest']:
            dview.execute('model = RandomForestRegressor(n_estimators=i, max_depth=j)')
            dview.execute('scores = cross_val_score(model, X, y, scoring=\'r2\', cv=3)')
    #return dview.gather('scores')

# %%
parallel_r2(dview,nest1,m_d1)
# Out:
# [0:execute]:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)<ipython-input-64-9057f51e6280> in <module>()
# ----> 1 scores = cross_val_score(model, X, y, scoring='r2', cv=3)
# /Users/leahbakst/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, score_func, pre_dispatch)
#    1150         delayed(_cross_val_score)(clone(estimator), X, y, scorer, train, test,
#    1151                                   verbose, fit_params)
# -> 1152         for train, test in cv)
#    1153     return np.array(scores)
#    1154
# /Users/leahbakst/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     515         try:
#     516             for function, args, kwargs in iterable:
# --> 517                 self.dispatch(function, args, kwargs)
#     518
# ...
